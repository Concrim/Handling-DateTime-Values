# %% [markdown]
# # Handling Date-Time Values

# %%
import pandas as pd
import numpy as np

# %%
date = pd.read_csv('stuff/orders.csv')
time = pd.read_csv('stuff/messages.csv')

# %%
date.head()
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-10        5628       25       3
# 1  2018-08-15        3646       14     157
# 2  2018-10-23        1859       25       1
# 3  2019-08-17        7292       25       1
# 4  2019-01-06        4344       25       3

# %%
time.head()
# Out:
#                   date                                                msg
# 0  2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1  2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2  2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3  2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4  2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше

# %% [markdown]
# ### Working with Dates

# %%
date['date'] = pd.to_datetime(date['date'])

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 31.4 KB

# %%
# Extract Year, Month, Day
date['date_year'] = date['date'].dt.year
date['date_month'] = date['date'].dt.month
date['month_name'] = date['date'].dt.month_name()
date['date_day'] = date['date'].dt.day

# %%
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month  \
# 0 2019-12-10        5628       25       3       2019          12
# 1 2018-08-15        3646       14     157       2018           8
# 2 2018-10-23        1859       25       1       2018          10
# 3 2019-08-17        7292       25       1       2019           8
# 4 2019-01-06        4344       25       3       2019           1
#
#                                           month_name  date_day
# 0  <bound method PandasDelegate._add_delegate_acc...        10
# 1  <bound method PandasDelegate._add_delegate_acc...        15
# 2  <bound method PandasDelegate._add_delegate_acc...        23
# 3  <bound method PandasDelegate._add_delegate_acc...        17
# 4  <bound method PandasDelegate._add_delegate_acc...         6

# %%
# Extract day of week
date['date_dow_name'] = date['date'].dt.day_name() # gives string name
date['date_dow_num'] = date['date'].dt.dayofweek # gives week num

# %%
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month  \
# 0 2019-12-10        5628       25       3       2019          12
# 1 2018-08-15        3646       14     157       2018           8
# 2 2018-10-23        1859       25       1       2018          10
# 3 2019-08-17        7292       25       1       2019           8
# 4 2019-01-06        4344       25       3       2019           1
#
#                                           month_name  date_day date_dow_name  \
# 0  <bound method PandasDelegate._add_delegate_acc...        10       Tuesday
# 1  <bound method PandasDelegate._add_delegate_acc...        15     Wednesday
# 2  <bound method PandasDelegate._add_delegate_acc...        23       Tuesday
# 3  <bound method PandasDelegate._add_delegate_acc...        17      Saturday
# 4  <bound method PandasDelegate._add_delegate_acc...         6        Sunday
#
#    date_dow_num
# 0             1
# 1             2
# 2             1
# 3             5
# 4             6

# %%
# Checking if it's a weekend
date['date_is_weekend'] = np.where(date['date_dow_name'].isin(['Sunday','Saturday',]), 1,0)
date.drop(columns=['product_id','city_id','orders'], inplace=True)
date.head()
# Out:
#         date  date_year  date_month  \
# 0 2019-12-10       2019          12
# 1 2018-08-15       2018           8
# 2 2018-10-23       2018          10
# 3 2019-08-17       2019           8
# 4 2019-01-06       2019           1
#
#                                           month_name  date_day date_dow_name  \
# 0  <bound method PandasDelegate._add_delegate_acc...        10       Tuesday
# 1  <bound method PandasDelegate._add_delegate_acc...        15     Wednesday
# 2  <bound method PandasDelegate._add_delegate_acc...        23       Tuesday
# 3  <bound method PandasDelegate._add_delegate_acc...        17      Saturday
# 4  <bound method PandasDelegate._add_delegate_acc...         6        Sunday
#
#    date_dow_num  date_is_weekend
# 0             1                0
# 1             2                0
# 2             1                0
# 3             5                1
# 4             6                1

# %%
# Extract Year
date['date_week'] = date['date'].dt.isocalendar().week

# %%
date.head()
# Out:
#         date  date_year  date_month  \
# 0 2019-12-10       2019          12
# 1 2018-08-15       2018           8
# 2 2018-10-23       2018          10
# 3 2019-08-17       2019           8
# 4 2019-01-06       2019           1
#
#                                           month_name  date_day date_dow_name  \
# 0  <bound method PandasDelegate._add_delegate_acc...        10       Tuesday
# 1  <bound method PandasDelegate._add_delegate_acc...        15     Wednesday
# 2  <bound method PandasDelegate._add_delegate_acc...        23       Tuesday
# 3  <bound method PandasDelegate._add_delegate_acc...        17      Saturday
# 4  <bound method PandasDelegate._add_delegate_acc...         6        Sunday
#
#    date_dow_num  date_is_weekend  date_week
# 0             1                0         50
# 1             2                0         33
# 2             1                0         43
# 3             5                1         33
# 4             6                1          1

# %%
# Extract Quarter
date['quarter'] = date['date'].dt.quarter

# %%
date.head()
# Out:
#         date  date_year  date_month  \
# 0 2019-12-10       2019          12
# 1 2018-08-15       2018           8
# 2 2018-10-23       2018          10
# 3 2019-08-17       2019           8
# 4 2019-01-06       2019           1
#
#                                           month_name  date_day date_dow_name  \
# 0  <bound method PandasDelegate._add_delegate_acc...        10       Tuesday
# 1  <bound method PandasDelegate._add_delegate_acc...        15     Wednesday
# 2  <bound method PandasDelegate._add_delegate_acc...        23       Tuesday
# 3  <bound method PandasDelegate._add_delegate_acc...        17      Saturday
# 4  <bound method PandasDelegate._add_delegate_acc...         6        Sunday
#
#    date_dow_num  date_is_weekend  date_week  quarter
# 0             1                0         50        4
# 1             2                0         33        3
# 2             1                0         43        4
# 3             5                1         33        3
# 4             6                1          1        1

# %%
# Extract Semester (1st or 2nd)
date['semester'] = np.where(date['quarter'].isin([1,2]), 1, 2)

# %%
date.head()
# Out:
#         date  date_year  date_month month_name  date_day date_dow_name  \
# 0 2019-12-10       2019          12   December        10       Tuesday
# 1 2018-08-15       2018           8     August        15     Wednesday
# 2 2018-10-23       2018          10    October        23       Tuesday
# 3 2019-08-17       2019           8     August        17      Saturday
# 4 2019-01-06       2019           1    January         6        Sunday
#
#    date_dow_num  date_is_weekend  date_week  quarter  semester
# 0             1                0         50        4         2
# 1             2                0         33        3         2
# 2             1                0         43        4         2
# 3             5                1         33        3         2
# 4             6                1          1        1         1

# %%
# Extract time elapsed between dates
from datetime import datetime as dt
today = dt.today()

elapsed = today  - date['date'][0] # 24.07.2024 - 10.12.2019
elapsed
# Out:
# Timedelta('1688 days 21:17:01.453866')

# %%
time.head()
# Out:
#                   date                                                msg
# 0  2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1  2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2  2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3  2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4  2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше

# %%
time['date'] = pd.to_datetime(time['date'])

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   datetime64[ns]
#  1   msg     1000 non-null   object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 15.8+ KB

# %%
time['hour'] = time['date'].dt.hour
time['minute'] = time['date'].dt.minute
time['second'] = time['date'].dt.second

# %%
time.head()
# Out:
#                  date                                                msg  \
# 0 2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1 2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2 2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3 2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4 2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
#
#    hour  minute  second
# 0     0      50       0
# 1    23      40       0
# 2     0      21       0
# 3     0      31       0
# 4    23      11       0

# %%
time['time'] = time['date'].dt.time

# %%
time.head()
# Out:
#                  date  hour  minute  second      time
# 0 2013-12-15 00:50:00     0      50       0  00:50:00
# 1 2014-04-29 23:40:00    23      40       0  23:40:00
# 2 2012-12-30 00:21:00     0      21       0  00:21:00
# 3 2014-11-28 00:31:00     0      31       0  00:31:00
# 4 2013-10-26 23:11:00    23      11       0  23:11:00
